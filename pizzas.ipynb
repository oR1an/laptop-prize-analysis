# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy 
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\ryan\datasets\pizzas.csv")
df
# Out:
#     diametro  preco
# 0         20     50
# 1         22     55
# 2         24     60
# 3         26     65
# 4         28     70
# 5         30     75
# 6         32     80
# 7         34     85
# 8         36     90
# 9         38     95
# 10        40    100

# %%
df
# Out:
#     diametro  preco
# 0         20     50
# 1         22     55
# 2         24     60
# 3         26     65
# 4         28     70
# 5         30     75
# 6         32     80
# 7         34     85
# 8         36     90
# 9         38     95
# 10        40    100

# %%
df.describe()
# Out:
#        diametro       preco
# count  11.00000   11.000000
# mean   30.00000   75.000000
# std     6.63325   16.583124
# min    20.00000   50.000000
# 25%    25.00000   62.500000
# 50%    30.00000   75.000000
# 75%    35.00000   87.500000
# max    40.00000  100.000000

# %%
x = df["diametro"]
y = df["preco"]

plt.scatter(x,y)
plt.show()

# %%
model = linear_model.LinearRegression()
#Modelo criado, regressão linear

x = df[["diametro"]]
y = df[["preco"]]
#Informar valores, obs: usar [[]], pois criar um dataframe, usar um, puxa apenas os dados da coluna

model.fit(x,y)
# Out:
# LinearRegression()

# %%
print(model.predict([[246]])[0][0])
# Out:
# 615.0000000000003
# c:\Users\ryan\pmg\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
